# %% [markdown]
# <a href="https://colab.research.google.com/github/alifahmed777/Blood_Donor_Alif-2202012/blob/main/blood_donor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset=pd.read_csv('/content/blood_donor_dataset.csv')
dataset.head()
# Out:
#      donor_id              name                          email    password  \
# 0  1b8b4c828a      Norma Fisher            ysullivan@yahoo.com  P5hX6Syg*A
# 1  a6a3f7fe55     Eugene Bowman       hramos@brown-sellers.com  b6Wq6Cqz@5
# 2  cee6478144  Sheri Bolton DDS          jasmine85@hotmail.com  $9RB51m#s7
# 3  5986bc55f9        Kelly Boyd  pattylawrence@riley-hayes.com  @5Tdg(4kCm
# 4  93246afe6c     Taylor Guzman       martinezjacob@wilson.com  x!)9Ag@J*7
#
#   contact_number       city blood_group availability  \
# 0  +61 461706749     Hobart          A+           No
# 1  +61 450709944     Darwin         AB-          Yes
# 2  +61 428756361  Melbourne         AB+          Yes
# 3  +61 454318320     Darwin          A-           No
# 4  +61 484158472     Darwin          O-           No
#
#    months_since_first_donation  number_of_donation  pints_donated  created_at
# 0                           65                  31             62  2017-03-17
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   donor_id                     10000 non-null  object
#  1   name                         10000 non-null  object
#  2   email                        10000 non-null  object
#  3   password                     10000 non-null  object
#  4   contact_number               10000 non-null  object
#  5   city                         10000 non-null  object
#  6   blood_group                  10000 non-null  object
#  7   availability                 10000 non-null  object
#  8   months_since_first_donation  10000 non-null  int64
#  9   number_of_donation           10000 non-null  int64
#  10  pints_donated                10000 non-null  int64
#  11  created_at                   10000 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 937.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
dataset['donor_id']=lb.fit_transform(dataset.donor_id)
dataset['name']=lb.fit_transform(dataset.name)
dataset['email']=lb.fit_transform(dataset.email)
dataset['password']=lb.fit_transform(dataset.password)
dataset['contact_number']=lb.fit_transform(dataset.contact_number)
dataset['city']=lb.fit_transform(dataset.city)
dataset['availability']=lb.fit_transform(dataset.availability)
dataset['created_at']=lb.fit_transform(dataset.created_at)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   donor_id                     10000 non-null  int64
#  1   name                         10000 non-null  int64
#  2   email                        10000 non-null  int64
#  3   password                     10000 non-null  int64
#  4   contact_number               10000 non-null  int64
#  5   city                         10000 non-null  int64
#  6   blood_group                  10000 non-null  object
#  7   availability                 10000 non-null  int64
#  8   months_since_first_donation  10000 non-null  int64
#  9   number_of_donation           10000 non-null  int64
#  10  pints_donated                10000 non-null  int64
#  11  created_at                   10000 non-null  int64
# dtypes: int64(11), object(1)
# memory usage: 937.6+ KB

# %%
dataset.head()
# Out:
#    donor_id  name  email  password  contact_number  city blood_group  \
# 0      1095  7075   9828      6073            5812     4          A+
# 1      6562  3070   3555      7859            4555     3         AB-
# 2      8127  8234   3894       855            2086     5         AB+
# 3      3504  5121   6905      4595            4974     3          A-
# 4      5768  8644   5665      9747            8277     3          O-
#
#    availability  months_since_first_donation  number_of_donation  \
# 0             0                           65                  31
# 1             1                           64                   8
# 2             1                           39                   6
# 3             0                           55                  20
# 4             0                            7                  35
#
#    pints_donated  created_at
# 0             62         591
# 1             16         471
# 2              6        2272
# 3             20        3326
# ...

# %%
dataset['donor_id']=dataset.donor_id.fillna(dataset.donor_id.mode()[0])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   donor_id                     10000 non-null  int64
#  1   name                         10000 non-null  int64
#  2   email                        10000 non-null  int64
#  3   password                     10000 non-null  int64
#  4   contact_number               10000 non-null  int64
#  5   city                         10000 non-null  int64
#  6   blood_group                  10000 non-null  object
#  7   availability                 10000 non-null  int64
#  8   months_since_first_donation  10000 non-null  int64
#  9   number_of_donation           10000 non-null  int64
#  10  pints_donated                10000 non-null  int64
#  11  created_at                   10000 non-null  int64
# dtypes: int64(11), object(1)
# memory usage: 937.6+ KB

# %%
dataset.describe()
# Out:
#           donor_id          name         email     password  contact_number  \
# count  10000.00000  10000.000000  10000.000000  10000.00000    10000.000000
# mean    4999.50000   4720.902100   4978.746100   4999.50000     4998.712200
# std     2886.89568   2708.057858   2874.101726   2886.89568     2886.551899
# min        0.00000      0.000000      0.000000      0.00000        0.000000
# 25%     2499.75000   2364.750000   2491.750000   2499.75000     2498.750000
# 50%     4999.50000   4722.500000   4978.500000   4999.50000     4998.500000
# 75%     7499.25000   7053.250000   7467.250000   7499.25000     7498.250000
# max     9999.00000   9418.000000   9953.000000   9999.00000     9997.000000
#
#                city  availability  months_since_first_donation  \
# count  10000.000000  10000.000000                 10000.000000
# mean       3.482600      0.508500                    59.953100
# std        2.293823      0.499953                    34.911379
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset['blood_group'],dataset.number_of_donation)
plt.title("Scatter plot")
plt.xlabel("blood_group")
plt.ylabel("number_of_donation")
plt.show();

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
dataset['blood_group']=lb.fit_transform(dataset.blood_group)

# %%
x=dataset.drop(columns=['email'])
y=dataset['email']

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest,ytrain,ytest=train_test_split(
    x,y,random_state=42,test_size=0.2
)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(xtrain,ytrain)
lr.score(xtest,ytest)
# Out:
# -0.003633245721521794

# %%
from sklearn.metrics import mean_squared_error as mse
predicted = lr.predict(xtest)
error = mse(ytest, predicted) ** .5
print(error)
# Out:
# 2901.766383472532

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# Example: your training data
# xtrain, xtest, ytrain, ytest = ...

models = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "SVR": SVR(),
    "KNeighbors": KNeighborsRegressor(),
    "DecisionTree": DecisionTreeRegressor(),
    "RandomForest": RandomForestRegressor(),
    "GradientBoosting": GradientBoostingRegressor(),
    "AdaBoost": AdaBoostRegressor()
}

scores = {}

# Compute R² scores using cross-validation
for name, model in models.items():
    pipe = make_pipeline(StandardScaler(), model)
    cv_score = cross_val_score(pipe, xtrain, ytrain, cv=5, scoring='r2')
    mean_score = np.mean(cv_score) * 100  # convert to percentage
    scores[name] = mean_score

# Shift scores if all are negative
min_score = min(scores.values())
if min_score < 0:
    shift = abs(min_score)
    shifted_scores = {k: v + shift for k, v in scores.items()}
else:
    shifted_scores = scores

# Plotting
sorted_scores = dict(sorted(shifted_scores.items(), key=lambda x: x[1]))

plt.figure(figsize=(12, 6))
bars = plt.barh(list(sorted_scores.keys()), list(sorted_scores.values()), color='skyblue')
plt.xlabel("Shifted R² Score (for visualization only)")
plt.title("Model Comparison (Shifted to Positive for Display)")
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Annotate the true R² scores on the bars
for bar, (model_name, shifted_val) in zip(bars, sorted_scores.items()):
    true_val = scores[model_name]
    plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2,
             f"True: {true_val:.2f}%", va='center')

plt.tight_layout()
plt.show()
